# %%
import numpy as np
import pandas as pd

# %%
# series from list

# string

country = ['India', 'Pakistan', 'Nepal', 'Srilanka', 'China']

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2       Nepal
# 3    Srilanka
# 4       China
# dtype: object

# %%
# integers
 
runs = [100,150,50,90,10]
new_runs = pd.Series(runs)
new_runs
# Out:
# 0    100
# 1    150
# 2     50
# 3     90
# 4     10
# dtype: int64

# %%
# custom index

marks = [30,55,79,100,35]
subjects = ['english', 'maths', 'Hindi', 'Science', 'History']

pd.Series(marks, index = subjects)
# Out:
# english     30
# maths       55
# Hindi       79
# Science    100
# History     35
# dtype: int64

# %%
# setting a name

pd.Series(marks, index = subjects, name = 'Final marksheet')
# Out:
# english     30
# maths       55
# Hindi       79
# Science    100
# History     35
# Name: Final marksheet, dtype: int64

# %%
marks = pd.Series(marks, index = subjects, name = 'Final marksheet')
marks
# Out:
# english     30
# maths       55
# Hindi       79
# Science    100
# History     35
# Name: Final marksheet, dtype: int64

# %%
# Series from dict

marks = {'english': 30,
         'maths'  : 55,
         'Hindi'  : 79,
         'Science':100 }

new_marks = pd.Series(marks, name = 'final marksheet')
new_marks
# Out:
# english     30
# maths       55
# Hindi       79
# Science    100
# Name: final marksheet, dtype: int64

# %%
new_marks[-1]
# Out:
# 100

# %%
# Series Attributes
new_marks.size
# Out:
# 4

# %%
new_marks.dtype
# Out:
# dtype('int64')

# %%
new_marks.name
# Out:
# 'final marksheet'

# %%
# to check duplicates

new_marks.is_unique
# Out:
# True

# %%
new_marks.index
# Out:
# Index(['english', 'maths', 'Hindi', 'Science'], dtype='object')

# %%
new_marks.values
# Out:
# array([ 30,  55,  79, 100], dtype=int64)

# %%
type(new_marks.values)
# Out:
# numpy.ndarray

# %%
type(pd.read_excel('subs.xlsx', squeeze = True))
# Out:
# pandas.core.series.Series

# %%
subs = pd.read_excel('subs.xlsx', squeeze = True)

# %%
subs
# Out:
# 0       48.0
# 1       57.0
# 2       40.0
# 3       43.0
# 4       44.0
#        ...
# 360    231.0
# 361    226.0
# 362    155.0
# 363    144.0
# 364    172.0
# Name: Subscribers gained, Length: 365, dtype: float64

# %%
subs.sum()
# Out:
# 49510.0

# %%
subs.min()
# Out:
# 33.0

# %%
subs.max()
# Out:
# 396.0

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
subs.mean()
# Out:
# 135.64383561643837

# %%
subs.std()
# Out:
# 62.67502303725269

# %%
subs.cumsum()
# Out:
# 0         48.0
# 1        105.0
# 2        145.0
# 3        188.0
# 4        232.0
#         ...
# 360    48813.0
# 361    49039.0
# 362    49194.0
# 363    49338.0
# 364    49510.0
# Name: Subscribers gained, Length: 365, dtype: float64

# %%
vk = pd.read_csv('kohli_ipl.csv', index_col= 'match_no' , squeeze= True)
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
vk.sum()
# Out:
# 6634

# %%
vk.median()
# Out:
# 24.0

# %%
vk.var()
# Out:
# 688.0024777222344

# %%
vk.cumsum()
# Out:
# match_no
# 1         1
# 2        24
# 3        37
# 4        49
# 5        50
#        ...
# 211    6509
# 212    6529
# 213    6602
# 214    6627
# 215    6634
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending = False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
#       ...
# 93       0
# 211      0
# 130      0
# 8        0
# 135      0
# Name: runs, Length: 215, dtype: int64

# %%
vk.count()
# Out:
# 215

# %%
vk.size
# Out:
# 215

# %%
len(vk)
# Out:
# 215

# %%
vk.max()
# Out:
# 113

# %%
# method chaining
vk.sort_values(ascending = False).head(1).values[0]
# Out:
# 113

# %%
movies = pd.read_excel('bollywood.xlsx', index_col = 'movie', squeeze = True)

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.mode()
# Out:
# 0    Akshay Kumar
# dtype: object

# %%
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index(inplace=True)

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.sample()
# Out:
# movie
# Dasvidaniya    Vinay Pathak
# Name: lead, dtype: object

# %%
movies.sample(5)
# Out:
# movie
# Sikandar (2009 film)         Parzaan Dastur
# Life Ki Toh Lag Gayi          Kay Kay Menon
# Dhadak                       Ishaan Khattar
# Begum Jaan                 Amitabh Bachchan
# Miss Tanakpur Haazir Ho         Rahul Bagga
# Name: lead, dtype: object

# %%
movies.value_counts()
# Out:
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
#                       ..
# Mukesh Khanna          1
# Talha Arshad Reshi     1
# Paoli Dam              1
# Amita Pathak           1
# Meghan Jadhav          1
# Name: lead, Length: 566, dtype: int64

# %%
# series indexing

# %%
# integer indexing

x = pd.Series([12,15,19,5,67,80,100])
x
# Out:
# 0     12
# 1     15
# 2     19
# 3      5
# 4     67
# 5     80
# 6    100
# dtype: int64

# %%
x[0]
# Out:
# 12

# %%
# negative indexing
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-60055cb99cf0> in <module>
#       1 # negative indexing
# ----> 2 x[-1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
movies[0]
# Out:
# 'Rajniesh Duggall'

# %%
movies["1920 (film)"]
# Out:
# 'Rajniesh Duggall'

# %%
movies[-1]
# Out:
# 'Meghan Jadhav'

# %%
# slicing
vk[5:15]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# Name: runs, dtype: int64

# %%
# runs made in last 5 matches

vk[-5:].sum()
# Out:
# 125

# %%
movies[-5:]
# Out:
# movie
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, dtype: object

# %%
# fetch alternate movies

movies[::2]
# Out:
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: The Evil Returns           Vicky Ahuja
# 2 States (2014 film)            Arjun Kapoor
# 3 A.M. (2014 film)             Salil Acharya
# 3 Idiots                          Aamir Khan
#                                   ...
# Zero (2018 film)              Shah Rukh Khan
# Zila Ghaziabad                  Vivek Oberoi
# Zindaggi Rocks                  Sushmita Sen
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zokkomon                     Darsheel Safary
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing
vk[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk[[1,3,4,5]].sum()
# Out:
# 27

# %%
# indexing with labels

movies["Zokkomon"]
# Out:
# 'Darsheel Safary'

# %%
movies[["Zokkomon", "Zindaggi Rocks"]].values
# Out:
# array(['Darsheel Safary', 'Sushmita Sen'], dtype=object)

# %%
# editing series

# %%
# using indexing

new_marks[0]= 70
new_marks
# Out:
# english     70
# maths       55
# Hindi       79
# Science    100
# Name: final marksheet, dtype: int64

# %%
new_marks["SSt"] = 60
new_marks
# Out:
# english     70
# maths       55
# Hindi       79
# Science    100
# SSt         60
# Name: final marksheet, dtype: int64

# %%
# slicing - multiple items editing

new_runs[2:4] = [100,75]
new_runs
# Out:
# 0    100
# 1    150
# 2    100
# 3     75
# 4     10
# dtype: int64

# %%
# fancy indexing

new_runs[[0,3,4]] = [0,0,0]
new_runs
# Out:
# 0      0
# 1    150
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# using index label
movies["3 Idiots"] = "Kareena Kapoor"
movies[:10]
# Out:
# movie
# 1920 (film)               Rajniesh Duggall
# 1920: London                 Sharman Joshi
# 1920: The Evil Returns         Vicky Ahuja
# 1971 (2007 film)            Manoj Bajpayee
# 2 States (2014 film)          Arjun Kapoor
# 22 Yards                       Barun Sobti
# 3 A.M. (2014 film)           Salil Acharya
# 3 Deewarein               Naseeruddin Shah
# 3 Idiots                    Kareena Kapoor
# 3 Storeys                      Aisha Ahmed
# Name: lead, dtype: object

# %%
dir(subs)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
movies.nunique()
# Out:
# 566

# %%
sorted(subs)
# Out:
# [33.0,
#  33.0,
#  35.0,
#  37.0,
#  39.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  42.0,
#  42.0,
#  43.0,
#  44.0,
#  44.0,
#  44.0,
#  45.0,
#  46.0,
#  46.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  49.0,
#  50.0,
#  50.0,
#  50.0,
#  51.0,
#  54.0,
#  56.0,
#  56.0,
#  56.0,
#  56.0,
#  57.0,
#  61.0,
#  62.0,
#  64.0,
#  65.0,
#  65.0,
#  66.0,
#  66.0,
#  66.0,
#  66.0,
#  67.0,
#  68.0,
#  70.0,
#  70.0,
#  70.0,
#  71.0,
#  71.0,
#  72.0,
#  72.0,
#  72.0,
#  72.0,
#  72.0,
#  73.0,
#  74.0,
#  74.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  90.0,
#  90.0,
#  91.0,
#  92.0,
#  92.0,
#  92.0,
#  93.0,
#  93.0,
#  93.0,
#  93.0,
#  95.0,
# ...

# %%
# type conversion
type(new_marks)
# Out:
# pandas.core.series.Series

# %%
list(new_marks)
# Out:
# [70, 55, 79, 100, 60]

# %%
dict(new_marks)
# Out:
# {'english': 70, 'maths': 55, 'Hindi': 79, 'Science': 100, 'SSt': 60}

# %%
# membership operator - only works on index

"3 Storeys" in movies
# Out:
# True

# %%
"Kareena Kapoor" in movies
# Out:
# False

# %%
"Kareena Kapoor" in movies.values
# Out:
# True

# %%
# looping

for i in movies:
    print(i)
# Out:
# Rajniesh Duggall
# Sharman Joshi
# Vicky Ahuja
# Manoj Bajpayee
# Arjun Kapoor
# Barun Sobti
# Salil Acharya
# Naseeruddin Shah
# Kareena Kapoor
# Aisha Ahmed
# Soha Ali Khan
# Akshaye Khanna
# Neil Nitin Mukesh
# Sara Arjun
# Nargis Fakhri
# Mouli Ganguly
# Vipin Sharma
# Priyanka Chopra
# Juhi Chawla
# Atul Kulkarni
# Kunal Khemu
# Shawar Ali
# Kiran Bhatia
# Shabana Azmi
# Jimmy Sheirgill
# Tiger Shroff
# Sidharth Malhotra
# Prabhu Deva
# Neil Nitin Mukesh
# Govinda
# Naveen Bawa
# Amitabh Bachchan
# Shreyas Talpade
# Sudesh Berry
# Madhuri Dixit
# Paul Sidhu
# Ajay Devgn
# Omkar Das Manikpuri
# Shatrughan Sinha
# Arun Bakshi
# Amitabh Bachchan
# Himesh Reshammiya
# Akshaye Khanna
# Priyanshu Chatterjee
# Amitabh Bachchan
# John Abraham
# Emraan Hashmi
# Aditya Roy Kapoor
# Ishaan Manhaas
# Hrishitaa Bhatt
# Sachiin Joshi
# Nana Patekar
# Amitabh Bachchan
# Farooq Shaikh
# Fardeen Khan
# Prabhas
# Akshay Kumar
# Rahul Dev
# Ranbir Kapoor
# Amitabh Bachchan
# Kareena Kapoor
# ...

# %%
for i in movies.index:
    print(i)
# Out:
# 1920 (film)
# 1920: London
# 1920: The Evil Returns
# 1971 (2007 film)
# 2 States (2014 film)
# 22 Yards
# 3 A.M. (2014 film)
# 3 Deewarein
# 3 Idiots
# 3 Storeys
# 31st October (film)
# 36 China Town
# 3G (film)
# 404 (film)
# 5 Weddings
# 68 Pages
# 7 Hours to Go
# 7 Khoon Maaf
# 7½ Phere
# 88 Antop Hill
# 99 (2009 film)
# 99.9 FM (film)
# ?: A Question Mark
# A Decent Arrangement
# A Flat (film)
# A Flying Jatt
# A Gentleman
# ABCD 2
# Aa Dekhen Zara
# Aa Gaya Hero
# Aabra Ka Daabra
# Aag (2007 film)
# Aagey Se Right
# Aaj Ka Andha Kanoon
# Aaja Nachle
# Aakhari Decision
# Aakrosh (2010 film)
# Aalaap (film)
# Aan: Men at Work
# Aanch
# Aankhen (2002 film)
# Aap Kaa Surroor
# Aap Ki Khatir (2006 film)
# Aapko Pehle Bhi Kahin Dekha Hai
# Aarakshan
# Aashayein
# Aashiq Banaya Aapne
# Aashiqui 2
# Aashiqui.in
# Aasma: The Sky Is the Limit
# Aazaan
# Ab Tak Chhappan 2
# Ab Tumhare Hawale Watan Saathiyo
# Accident on Hill Road
# Acid Factory
# Action Jackson (2014 film)
# ...

# %%
new_marks
# Out:
# english     70
# maths       55
# Hindi       79
# Science    100
# SSt         60
# Name: final marksheet, dtype: int64

# %%
# relational operators

new_marks >= 100
# Out:
# english    False
# maths      False
# Hindi      False
# Science     True
# SSt        False
# Name: final marksheet, dtype: bool

# %%
new_marks[new_marks < 100]
# Out:
# english    70
# maths      55
# Hindi      79
# SSt        60
# Name: final marksheet, dtype: int64

# %%
# broadcasting
# arithmetic operators
 
100 - new_marks
# Out:
# english    30
# maths      45
# Hindi      21
# Science     0
# SSt        40
# Name: final marksheet, dtype: int64

# %%
# in how many matches VK scored more than 50 runs

vk[vk >= 50].size
# Out:
# 50

# %%
# in how many matches VK scored less than 10 runs
vk[vk <= 10].size
# Out:
# 58

# %%
len(vk[vk <= 10])
# Out:
# 58

# %%
len(vk[vk ==0])
# Out:
# 9

# %%
# more than 200 subs in each day

subs[subs >= 200].size
# Out:
# 59

# %%
num_movies = movies.value_counts()
num_movies[num_movies >= 20]
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: lead, dtype: int64

# %%
# plotting graph on series

subs.plot()

# %%
movies.value_counts().head(20).plot(kind='bar')

# %%
movies.value_counts().head(20).plot(kind='pie')
